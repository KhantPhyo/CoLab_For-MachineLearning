# %% [markdown]
# <a href="https://colab.research.google.com/github/KhantPhyo/CoLab_For-MachineLearning/blob/main/B.24%20plt_3d_surface_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.tutorialspoint.com/matplotlib/matplotlib_3d_surface_plot.htm
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.outer(np.linspace(-2, 2, 30), np.ones(30))
y = x.copy().T # transpose
z = np.cos(x ** 2 + y ** 2)
x.shape, y.shape, z.shape
# Out:
# ((30, 30), (30, 30), (30, 30))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()

# %%
x = np.outer(np.linspace(-2, 2, 30), np.ones(30))
y = x.copy().T # transpose
z = np.sqrt(x ** 2 + y ** 2)
x.shape, y.shape, z.shape
# Out:
# ((30, 30), (30, 30), (30, 30))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()

# %%
x = np.outer(np.linspace(-2, 2, 30), np.ones(30))
y = x.copy().T # transpose
z = np.exp(x ** 2 + y ** 2)
x.shape, y.shape, z.shape
# Out:
# ((30, 30), (30, 30), (30, 30))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()

# %%
x = np.outer(np.linspace(-2, 2, 30), np.ones(30))
y = x.copy().T # transpose
z = np.sin(x ** 2 + y ** 2)
x.shape, y.shape, z.shape
# Out:
# ((30, 30), (30, 30), (30, 30))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z,cmap='viridis', edgecolor='none')
ax.set_title('Surface plot')
plt.show()
