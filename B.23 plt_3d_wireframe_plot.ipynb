# %% [markdown]
# <a href="https://colab.research.google.com/github/KhantPhyo/CoLab_For-MachineLearning/blob/main/B.23%20plt_3d_wireframe_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.tutorialspoint.com/matplotlib/matplotlib_3d_wireframe_plot.htm
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x, y):
   return np.sin(np.sqrt(x ** 2 + y ** 2))

# %%
#f = lambda x, y: np.sqrt(x ** 2 + y ** 2)
#f = lambda x, y: np.exp(x ** 2 + y ** 2)
f = lambda x, y: np.cos(np.sqrt(x ** 2 + y ** 2))

# %%
x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
X.shape, Y.shape, Z.shape
# Out:
# ((30, 30), (30, 30), (30, 30))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe')
plt.show()
