# %% [markdown]
# <a href="https://colab.research.google.com/github/KhantPhyo/CoLab_For-MachineLearning/blob/main/B.14%20plt_histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.tutorialspoint.com/matplotlib/matplotlib_histogram.htm
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])

# %%
fig,ax = plt.subplots(1,1)
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("histogram of result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()
